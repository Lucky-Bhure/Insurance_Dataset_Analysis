# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.count()
# Out:
# age         1338
# sex         1338
# bmi         1338
# children    1338
# smoker      1338
# region      1338
# charges     1338
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.sample(5)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1227   42    male  37.180         2     no  southeast   7162.01220
# 536    33  female  38.900         3     no  southwest   5972.37800
# 1262   41  female  28.050         1     no  southeast   6770.19250
# 1110   54  female  32.300         1     no  northeast  11512.40500
# 485    31  female  31.065         0     no  northeast   4347.02335

# %%
sns.countplot(data = df, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data = df, x = 'smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.pairplot(data = df, hue = 'sex')

# %%
df["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

df[["sex", "smoker", "region"]] = oe.fit_transform(df[["sex", "smoker", "region"]])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     1.0     3.0  16884.92400
# 1   18  1.0  33.770         1     0.0     2.0   1725.55230
# 2   28  1.0  33.000         3     0.0     2.0   4449.46200
# 3   33  1.0  22.705         0     0.0     1.0  21984.47061
# 4   32  1.0  28.880         0     0.0     1.0   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   float64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   float64
#  5   region    1338 non-null   float64
#  6   charges   1338 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 73.3 KB

# %%
sns.heatmap(df.corr(), annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19  0.0  27.900         0     1.0     3.0
# 1      18  1.0  33.770         1     0.0     2.0
# 2      28  1.0  33.000         3     0.0     2.0
# 3      33  1.0  22.705         0     0.0     1.0
# 4      32  1.0  28.880         0     0.0     1.0
# ...   ...  ...     ...       ...     ...     ...
# 1333   50  1.0  30.970         3     0.0     1.0
# 1334   18  0.0  31.920         0     0.0     0.0
# 1335   18  0.0  36.850         0     0.0     2.0
# 1336   21  0.0  25.800         0     0.0     3.0
# 1337   61  0.0  29.070         0     1.0     1.0
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest, ypred)
# Out:
# 0.762322402256339

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     1.0     3.0  16884.92400
# 1   18  1.0  33.770         1     0.0     2.0   1725.55230
# 2   28  1.0  33.000         3     0.0     2.0   4449.46200
# 3   33  1.0  22.705         0     0.0     1.0  21984.47061
# 4   32  1.0  28.880         0     0.0     1.0   3866.85520

# %% [markdown]
# x_age = int(input("Enter your age : "))
# x_sex = float(input("Enter your gender (female:0.0, male:1.0) :" ))
# x_bmi = float(input("Enter your bmi : "))
# x_child = int(input("Enter number of child : "))
# x_smoker = float(input("Smoker (Yes:1, No:0) : "))
# x_region = float(input("Enter your region (southwest:3.0, southeast:2.0, northwest:1.0, northeast:0.0) :"))
# xnew = [[x_age,x_sex,x_bmi,x_child,x_smoker,x_region]]
# yp = model.predict(xnew)
# print("Price will be ",yp)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
 
mae = mean_absolute_error(ytest,ypred)
mse = mean_squared_error(ytest,ypred) 
rmse = mean_squared_error(ytest,ypred,squared=False)
 
print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 4056.1183056626514
# MSE: 35480663.81217907
# RMSE: 5956.564766052584

# %%
#readge and lasso

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso

# %%
sc = StandardScaler()

# %%
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
model = Lasso(alpha = 1.0)
model.fit(xtrain, ytrain)
# Out:
# Lasso()

# %%
ypred = model.predict(xtest)

# %%
mse = mean_squared_error(ytest, ypred)
rmse = mean_squared_error(ytest,ypred,squared=False)

print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MSE: 867246194.4322906
# RMSE: 29449.044032570746
